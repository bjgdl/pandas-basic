# %%
import pandas as pd

# %%
bigmac=pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/bigmac.csv')
bigmac['Date'] = pd.to_datetime(bigmac['Date'])
bigmac.head()
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35
# 3 2016-01-01    Britain                 4.22
# 4 2016-01-01     Canada                 4.14

# %%
bigmac[bigmac["Country"].str.contains("Norway")]
# Out:
#           Date Country  Price in US Dollars
# 22  2016-01-01  Norway                 5.21
# 78  2015-07-01  Norway                 5.65
# 134 2015-01-01  Norway                 6.30
# 191 2014-07-01  Norway                 7.76
# 248 2014-01-01  Norway                 7.80
# 306 2013-07-01  Norway                 7.51
# 363 2013-01-01  Norway                 7.84
# 420 2012-07-01  Norway                 7.06
# 476 2012-01-01  Norway                 6.79
# 533 2011-07-01  Norway                 8.31
# 589 2010-07-01  Norway                 7.20
# 632 2010-01-01  Norway                 7.02

# %%
bigmac.set_index(keys=['Date','Country'],inplace=True)

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14

# %%
bigmac.sort_index(inplace=True)

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %%
### The .get_level_values() Method

# %%
bigmac=pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/bigmac.csv', parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %%
bigmac.index.set_names(['Day','Location'],inplace=True)

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac=pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/bigmac.csv', parse_dates=['Date'],index_col=['Date','Country'])

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14

# %%
bigmac.sort_index(ascending=False)
# Out:
#                            Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                        2.67
#            Venezuela                      0.66
#            Uruguay                        3.74
#            United States                  4.93
#            Ukraine                        1.54
#            UAE                            3.54
#            Turkey                         3.41
#            Thailand                       3.09
#            Taiwan                         2.08
#            Switzerland                    6.44
#            Sweden                         5.23
#            Sri Lanka                      2.43
#            Spain                          3.76
#            South Korea                    3.59
#            South Africa                   1.77
#            Singapore                      3.27
#            Saudi Arabia                   3.20
#            Russia                         1.53
# ...

# %%
bigmac.sort_index(ascending=[True,False],inplace=True)

# %%
bigmac.head()
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83
#            UAE                           2.99
#            Turkey                        3.83

# %%
bigmac=pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/bigmac.csv', parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.loc[("2010-01-01",'United States'),]
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 United States                 3.58

# %%
bigmac.loc[("2015-07-01","Chile"), "Price in US Dollars"]
# Out:
# Date        Country
# 2015-07-01  Chile      3.27
# Name: Price in US Dollars, dtype: float64

# %%
bigmac=bigmac.transpose()
bigmac.head(1)
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                     ...    2016-01-01  \
# Country             Colombia Costa Rica Czech Republic   ...   Switzerland
# Price in US Dollars     3.91       3.52           3.71   ...          6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.head(3)
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                     ...    2016-01-01  \
# Country             Colombia Costa Rica Czech Republic   ...   Switzerland
# Price in US Dollars     3.91       3.52           3.71   ...          6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc["Price in US Dollars",('2016-01-01','Denmark')]
# Out:
# Date        Country
# 2016-01-01  Denmark    4.32
# Name: Price in US Dollars, dtype: float64

# %%
bigmac=pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/bigmac.csv', parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac = bigmac.swaplevel()
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2010-01-01                 1.84
# Australia 2010-01-01                 3.98
# Brazil    2010-01-01                 4.76

# %% [markdown]
# ### The .stack() Method

# %%
world = pd.read_csv("/home/yuan002/Desktop/pandas for datascience/pandas dataset/worldstats.csv",index_col=["country","year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
type(world.stack())
# Out:
# pandas.core.series.Series

# %%
world.stack()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                   GDP           2.846994e+12
#             2012  Population    3.688026e+08
#                   GDP           2.773270e+12
#             2011  Population    3.610318e+08
#                   GDP           2.497945e+12
#             2010  Population    3.531122e+08
#                   GDP           2.103825e+12
#             2009  Population    3.450542e+08
#                   GDP           1.798878e+12
#             2008  Population    3.368865e+08
#                   GDP           2.081343e+12
#             2007  Population    3.287666e+08
#                   GDP           1.641666e+12
#             2006  Population    3.209067e+08
#                   GDP           1.404190e+12
# ...

# %%
world = pd.read_csv("/home/yuan002/Desktop/pandas for datascience/pandas dataset/worldstats.csv",index_col=["country","year"])
world
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
#            2010  353112237.0  2.103825e+12
#            2009  345054176.0  1.798878e+12
#            2008  336886468.0  2.081343e+12
#            2007  328766559.0  1.641666e+12
#            2006  320906736.0  1.404190e+12
#            2005  313430911.0  1.184735e+12
#            2004  306387415.0  9.639180e+11
#            2003  299731956.0  8.218702e+11
#            2002  293402563.0  7.279939e+11
#            2001  287291826.0  7.221506e+11
#            2000  281326250.0  7.339481e+11
#            1999  275503565.0  6.431349e+11
#            1998  269795252.0  5.905141e+11
#            1997  264153948.0  6.123037e+11
#            1996  258423164.0  5.773078e+11
# ...

# %%
world.stack()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                   GDP           2.846994e+12
#             2012  Population    3.688026e+08
#                   GDP           2.773270e+12
#             2011  Population    3.610318e+08
#                   GDP           2.497945e+12
#             2010  Population    3.531122e+08
#                   GDP           2.103825e+12
#             2009  Population    3.450542e+08
#                   GDP           1.798878e+12
#             2008  Population    3.368865e+08
#                   GDP           2.081343e+12
#             2007  Population    3.287666e+08
#                   GDP           1.641666e+12
#             2006  Population    3.209067e+08
#                   GDP           1.404190e+12
# ...

# %%
sales=pd.read_csv("/home/yuan002/Desktop/pandas for datascience/pandas dataset/salesmen.csv",parse_dates=['Date'])
sales["Salesman"] = sales["Salesman"].astype("category")
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales.pivot(index="Date",columns='Salesman',values="Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# 2016-01-06  1744  7859  8702   7794    5930
# 2016-01-07   918  8597  4250   9728    1933
# 2016-01-08  9863  3092  9719   5263    5709
# 2016-01-09  8337  1794  5614   7144    4707
# 2016-01-10  7543  7105   301   7663    8267
# 2016-01-11  1053  6851  9489   8888    1340
# 2016-01-12  4362  7147  8719   3092     279
# 2016-01-13  6812  6160  2349   6139    7540
# 2016-01-14  9047  7533  7690   5235    4214
# 2016-01-15  3594  9883  6917   5507    5346
# 2016-01-16  9800  3622   474   4947    9636
# 2016-01-17  7215  4565  8963   3325    6058
# 2016-01-18  7744  8246  2351   2611    3602
# 2016-01-19  9560  9229  5512   1905     316
# 2016-01-20  9863  8358  9509   6005    9352
# ...

# %%
sales=pd.read_csv("/home/yuan002/Desktop/pandas for datascience/pandas dataset/salesmen.csv",parse_dates=["Date"])

# %%
sales['Salesman']=sales['Salesman'].astype('category')

# %%
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales.pivot(index='Date',columns='Salesman', values= 'Revenue')
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# 2016-01-06  1744  7859  8702   7794    5930
# 2016-01-07   918  8597  4250   9728    1933
# 2016-01-08  9863  3092  9719   5263    5709
# 2016-01-09  8337  1794  5614   7144    4707
# 2016-01-10  7543  7105   301   7663    8267
# 2016-01-11  1053  6851  9489   8888    1340
# 2016-01-12  4362  7147  8719   3092     279
# 2016-01-13  6812  6160  2349   6139    7540
# 2016-01-14  9047  7533  7690   5235    4214
# 2016-01-15  3594  9883  6917   5507    5346
# 2016-01-16  9800  3622   474   4947    9636
# 2016-01-17  7215  4565  8963   3325    6058
# 2016-01-18  7744  8246  2351   2611    3602
# 2016-01-19  9560  9229  5512   1905     316
# 2016-01-20  9863  8358  9509   6005    9352
# ...

# %%
foods=pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/foods.csv')
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
foods.pivot_table(values='Spend',index='Gender',aggfunc='sum')
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],aggfunc='sum')
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
sales= pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/quarters.csv')
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(sales,id_vars="Salesman")
# Out:
#    Salesman variable   value
# 0     Boris       Q1  602908
# 1       Bob       Q1   43790
# 2     Tommy       Q1  392668
# 3    Travis       Q1  834663
# 4    Donald       Q1  580935
# 5       Ted       Q1  656644
# 6       Jeb       Q1  486141
# 7     Stacy       Q1  479662
# 8    Morgan       Q1  992673
# 9     Boris       Q2  233879
# 10      Bob       Q2  514863
# 11    Tommy       Q2  113579
# 12   Travis       Q2  266785
# 13   Donald       Q2  411379
# 14      Ted       Q2   70803
# 15      Jeb       Q2  600753
# 16    Stacy       Q2  742806
# 17   Morgan       Q2  879183
# 18    Boris       Q3  354479
# 19      Bob       Q3  297151
# 20    Tommy       Q3  430882
# 21   Travis       Q3  749238
# 22   Donald       Q3  110390
# 23      Ted       Q3  375948
# 24      Jeb       Q3  742716
# 25    Stacy       Q3  770712
# 26   Morgan       Q3   37945
# 27    Boris       Q4   32704
# 28      Bob       Q4  544493
# 29    Tommy       Q4  247231
# 30   Travis       Q4  570524
# ...

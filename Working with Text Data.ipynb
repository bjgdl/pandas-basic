# %%
import pandas as pd

# %%
chicago = pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/chicago.csv')
chicago['Department'] = chicago['Department'].astype('category')
chicago['Position Title'] = chicago['Position Title'].astype('category')
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null category
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(2), object(2)
# memory usage: 645.1+ KB

# %%
chicago['Department'].nunique()
# Out:
# 35

# %%
chicago['Position Title'].nunique()
# Out:
# 1093

# %%
chicago = pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/chicago.csv').dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago["Name"].str.lower().str.title()
# Out:
# 0                 Aaron,  Elvia J
# 1               Aaron,  Jeffery M
# 2                  Aaron,  Karina
# 3             Aaron,  Kimberlei R
# 4             Abad Jr,  Vicente M
# 5                 Abarca,  Anabel
# 6               Abarca,  Emmanuel
# 7               Abascal,  Reece E
# 8            Abbasi,  Christopher
# 9           Abbatacola,  Robert J
# 10          Abbatemarco,  James J
# 11               Abbate,  Terry M
# 12               Abbott,  Betty L
# 13              Abbott,  Lynise M
# 14         Abbruzzese,  William J
# 15                Abdallah,  Zaid
# 16          Abdelhadi,  Abdalmahd
# 17            Abdellatif,  Aref R
# 18             Abdelmajeid,  Aziz
# 19            Abdollahzadeh,  Ali
# 20       Abdul-Karim,  Muhammad A
# 21            Abdullah,  Daniel N
# 22               Abdullah,  Kevin
# 23           Abdullah,  Lakenya N
# 24            Abdullah,  Rashad J
# 25           Abdulsattar,  Mudhar
# 26           Abdul-Shakur,  Tahir
# ...

# %%
chicago['Name'].str.title().head(8)
# Out:
# 0        Aaron,  Elvia J
# 1      Aaron,  Jeffery M
# 2         Aaron,  Karina
# 3    Aaron,  Kimberlei R
# 4    Abad Jr,  Vicente M
# 5        Abarca,  Anabel
# 6      Abarca,  Emmanuel
# 7      Abascal,  Reece E
# Name: Name, dtype: object

# %%
chicago['Position Title'] = chicago['Position Title'].str.title()

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          Water Rate Taker       WATER MGMNT
# 1    AARON,  JEFFERY M            Police Officer            POLICE
# 2       AARON,  KARINA            Police Officer            POLICE
# 3  AARON,  KIMBERLEI R  Chief Contract Expediter  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         Civil Engineer Iv       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago['Department']=chicago['Department'].str.replace('MGMNT','MANAGEMENT').str.upper().head(20)

# %%
chicago.head(10)
# Out:
#                     Name               Position Title        Department  \
# 0        AARON,  ELVIA J             Water Rate Taker  WATER MANAGEMENT
# 1      AARON,  JEFFERY M               Police Officer            POLICE
# 2         AARON,  KARINA               Police Officer            POLICE
# 3    AARON,  KIMBERLEI R     Chief Contract Expediter  GENERAL SERVICES
# 4    ABAD JR,  VICENTE M            Civil Engineer Iv  WATER MANAGEMENT
# 5        ABARCA,  ANABEL         Asst To The Alderman      CITY COUNCIL
# 6      ABARCA,  EMMANUEL        General Laborer - Dss     STREETS & SAN
# 7      ABASCAL,  REECE E  Traffic Control Aide-Hourly              OEMC
# 8   ABBASI,  CHRISTOPHER   Staff Asst To The Alderman      CITY COUNCIL
# 9  ABBATACOLA,  ROBERT J          Electrical Mechanic          AVIATION
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00
# ...

# %%
"Hello World".replace('l','!')
# Out:
# 'He!!o Wor!d'

# %%
chicago['Employee Annual Salary'].str.replace('$','').tail(10)
# Out:
# 32052     84450.00
# 32053     92682.00
# 32054     46668.00
# 32055     81588.00
# 32056     94328.00
# 32057     99528.00
# 32058     87384.00
# 32059     84450.00
# 32060     87384.00
# 32061    113664.00
# Name: Employee Annual Salary, dtype: object

# %%
chicago['Employee Annual Salary'].describe()
# Out:
# count         32062
# unique         1156
# top       $87384.00
# freq           2394
# Name: Employee Annual Salary, dtype: object

# %%
chicago['Employee Annual Salary']=chicago['Employee Annual Salary'].str.replace('$','').astype(float)

# %%
chicago['Employee Annual Salary'].describe()
# Out:
# count     32062.000000
# mean      80204.178634
# std       25098.329868
# min           0.960000
# 25%       72862.400000
# 50%       84450.000000
# 75%       93240.000000
# max      300000.000000
# Name: Employee Annual Salary, dtype: float64

# %%
chicago['Employee Annual Salary'].mean()
# Out:
# 80204.178633899

# %%
chicago['Employee Annual Salary'].nlargest(10)
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# 19208    195000.0
# 3706     187680.0
# 18556    187680.0
# 29466    187680.0
# 13754    185364.0
# Name: Employee Annual Salary, dtype: float64

# %%
mask=chicago['Position Title'].str.lower().str.contains('water')
chicago[mask].head()
# Out:
#                     Name                                 Position Title  \
# 0        AARON,  ELVIA J                               Water Rate Taker
# 554   ALUISE,  VINCENT G             Foreman Of Water Pipe Construction
# 671      ANDER,  PERRY A                               Water Chemist Ii
# 685  ANDERSON,  ANDREW J  District Superintendent Of Water Distribution
# 702    ANDERSON,  DONALD             Foreman Of Water Pipe Construction
#
#            Department  Employee Annual Salary
# 0    WATER MANAGEMENT                 90744.0
# 554               NaN                102440.0
# 671               NaN                 82044.0
# 685               NaN                109272.0
# 702               NaN                102440.0

# %%
chicago['Position Title']
# Out:
# 0                                     Water Rate Taker
# 1                                       Police Officer
# 2                                       Police Officer
# 3                             Chief Contract Expediter
# 4                                    Civil Engineer Iv
# 5                                 Asst To The Alderman
# 6                                General Laborer - Dss
# 7                          Traffic Control Aide-Hourly
# 8                           Staff Asst To The Alderman
# 9                                  Electrical Mechanic
# 10                                   Fire Engineer-Emt
# 11                                      Police Officer
# 12                                  Foster Grandparent
# 13                                           Clerk Iii
# 14                              Investigator - Ipra Ii
# 15                                      Police Officer
# 16                                      Police Officer
# ...

# %%
chicago = pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/chicago.csv').dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
"  hello World      ".lstrip().rstrip()
# Out:
# 'hello World'

# %%
chicago["Name"].str.lstrip().str.rstrip()
chicago['Position Title'].str.strip().head()
# Out:
# 0            WATER RATE TAKER
# 1              POLICE OFFICER
# 2              POLICE OFFICER
# 3    CHIEF CONTRACT EXPEDITER
# 4           CIVIL ENGINEER IV
# Name: Position Title, dtype: object

# %%
chicago = pd.read_csv('/home/yuan002/Desktop/pandas for datascience/pandas dataset/chicago.csv').dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago.columns=chicago.columns.str.upper()

# %%
chicago.head(3)
# Out:
#                 NAME    POSITION TITLE   DEPARTMENT EMPLOYEE ANNUAL SALARY
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago["NAME"].str.split(",")
# Out:
# 0                 [AARON,   ELVIA J]
# 1               [AARON,   JEFFERY M]
# 2                  [AARON,   KARINA]
# 3             [AARON,   KIMBERLEI R]
# 4             [ABAD JR,   VICENTE M]
# 5                 [ABARCA,   ANABEL]
# 6               [ABARCA,   EMMANUEL]
# 7               [ABASCAL,   REECE E]
# 8            [ABBASI,   CHRISTOPHER]
# 9           [ABBATACOLA,   ROBERT J]
# 10          [ABBATEMARCO,   JAMES J]
# 11               [ABBATE,   TERRY M]
# 12               [ABBOTT,   BETTY L]
# 13              [ABBOTT,   LYNISE M]
# 14         [ABBRUZZESE,   WILLIAM J]
# 15                [ABDALLAH,   ZAID]
# 16          [ABDELHADI,   ABDALMAHD]
# 17            [ABDELLATIF,   AREF R]
# 18             [ABDELMAJEID,   AZIZ]
# 19            [ABDOLLAHZADEH,   ALI]
# 20       [ABDUL-KARIM,   MUHAMMAD A]
# 21            [ABDULLAH,   DANIEL N]
# 22               [ABDULLAH,   KEVIN]
# 23           [ABDULLAH,   LAKENYA N]
# 24            [ABDULLAH,   RASHAD J]
# ...

# %%
chicago["NAME"].str.split(',').str.get(0).str.title().value_counts()
# Out:
# Williams       293
# Johnson        244
# Smith          241
# Brown          185
# Jones          183
# Rodriguez      171
# Jackson        136
# Garcia         130
# Davis          127
# Hernandez      110
# Martinez       108
# Lopez          106
# Gonzalez       104
# Perez          100
# Wilson          94
# Rivera          90
# Thomas          89
# Anderson        82
# Torres          81
# Murphy          80
# Robinson        79
# Moore           78
# Sanchez         76
# Harris          76
# Miller          75
# Lewis           74
# Taylor          73
# Martin          72
# Clark           66
# White           66
#               ...
# Przewoznik       1
# Burrows          1
# Vela             1
# Deluna Jr.       1
# Gasinski         1
# Carlassare       1
# Greb             1
# Hankins          1
# Chierici         1
# Woronko          1
# Lee Palmer       1
# Okere            1
# Blachut          1
# Dudzinski        1
# Haller           1
# Duhart           1
# ...

# %%
chicago['POSITION TITLE'].str.split(" ").str.get(0).value_counts().head(20)
# Out:
# POLICE             10856
# FIREFIGHTER-EMT     1509
# SERGEANT            1186
# POOL                 918
# FIREFIGHTER          810
# CROSSING             775
# MOTOR                721
# SANITATION           715
# PARAMEDIC            641
# ASST                 606
# TRAFFIC              512
# FIRE                 512
# SENIOR               470
# CONSTRUCTION         452
# LIEUTENANT-EMT       394
# ADMINISTRATIVE       375
# LIBRARY              365
# LIBRARIAN            335
# LIEUTENANT           332
# OPERATING            324
# Name: POSITION TITLE, dtype: int64

# %%
chicago['NAME'].str.split(",").str.get(0)
# Out:
# 0                 AARON
# 1                 AARON
# 2                 AARON
# 3                 AARON
# 4               ABAD JR
# 5                ABARCA
# 6                ABARCA
# 7               ABASCAL
# 8                ABBASI
# 9            ABBATACOLA
# 10          ABBATEMARCO
# 11               ABBATE
# 12               ABBOTT
# 13               ABBOTT
# 14           ABBRUZZESE
# 15             ABDALLAH
# 16            ABDELHADI
# 17           ABDELLATIF
# 18          ABDELMAJEID
# 19        ABDOLLAHZADEH
# 20          ABDUL-KARIM
# 21             ABDULLAH
# 22             ABDULLAH
# 23             ABDULLAH
# 24             ABDULLAH
# 25          ABDULSATTAR
# 26         ABDUL-SHAKUR
# 27           ABDULWAHAB
# 28              ABEJERO
# 29       ABERCROMBIE IV
#               ...
# 32032         ZUNIGA JR
# 32033            ZUNIGA
# 32034            ZUNIGA
# 32035            ZUNIGA
# 32036            ZUNIGA
# 32037            ZUNIGA
# 32038              ZUNO
# ...

# %%
chicago["NAME"].str.split(',').str.get(1).str.strip().str.split(" ").str.get(0).value_counts().head()
# Out:
# MICHAEL    1153
# JOHN        899
# JAMES       676
# ROBERT      622
# JOSEPH      537
# Name: NAME, dtype: int64

# %%
chicago[['First Name','Last Name']]=chicago['NAME'].str.split(",", expand=True)

# %%
chicago.head(3)
# Out:
#                 NAME    POSITION TITLE   DEPARTMENT EMPLOYEE ANNUAL SALARY  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00
#
#   First Name    Last Name
# 0      AARON      ELVIA J
# 1      AARON    JEFFERY M
# 2      AARON       KARINA

# %%
chicago["POSITION TITLE"].str.split(' ', expand=True)
# Out:
#                            0                     1            2  \
# 0                      WATER                  RATE        TAKER
# 1                     POLICE               OFFICER         None
# 2                     POLICE               OFFICER         None
# 3                      CHIEF              CONTRACT    EXPEDITER
# 4                      CIVIL              ENGINEER           IV
# 5                       ASST                    TO          THE
# 6                    GENERAL               LABORER            -
# 7                    TRAFFIC               CONTROL  AIDE-HOURLY
# 8                      STAFF                  ASST           TO
# 9                 ELECTRICAL              MECHANIC         None
# 10                      FIRE          ENGINEER-EMT         None
# 11                    POLICE               OFFICER         None
# 12                    FOSTER           GRANDPARENT         None
# 13                     CLERK                   III         None
# ...
